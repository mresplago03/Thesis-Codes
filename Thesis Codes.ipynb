# %% [markdown]
# Tangent

# %%
import sympy as sp

# Define symbols
k, t= sp.symbols('k t')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
#def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    #polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    #return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
#li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = (2/(sp.exp(2*t)+1))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 1
# E^(S)_1(x, y) = -1
# E^(S)_2(x, y) = 0
# E^(S)_3(x, y) = 2
# E^(S)_4(x, y) = 0
# T^(S)_0(x, y) = 1
# T^(S)_1(x, y) = x - 1
# T^(S)_2(x, y) = x**2 - 2*x
# T^(S)_3(x, y) = x**3 - 3*x**2 + 2
# T^(S)_4(x, y) = x**4 - 4*x**3 + 8*x

# %% [markdown]
# Frobenius Euler

# %%
import sympy as sp

# Define symbols
k, t, u= sp.symbols('k t u')

# Set u = -1
#u = -1

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
#def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    #polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    #return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
#li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((1-u)/(sp.exp(t)-u))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = -u/(1 - u) + 1/(1 - u)
# E^(S)_1(x, y) = -u/((1 - u)*(u - 1)) + 1/((1 - u)*(u - 1))
# E^(S)_2(x, y) = -2*u*(1/(2*(u - 1)) + (u - 1)**(-2))/(1 - u) + 2*(1/(2*(u - 1)) + (u - 1)**(-2))/(1 - u)
# E^(S)_3(x, y) = -6*u*(1/(6*(u - 1)) + (u - 1)**(-2) + (u - 1)**(-3))/(1 - u) + 6*(1/(6*(u - 1)) + (u - 1)**(-2) + (u - 1)**(-3))/(1 - u)
# E^(S)_4(x, y) = -24*u*(1/(24*(u - 1)) + 7/(12*(u - 1)**2) + 3/(2*(u - 1)**3) + (u - 1)**(-4))/(1 - u) + 24*(1/(24*(u - 1)) + 7/(12*(u - 1)**2) + 3/(2*(u - 1)**3) + (u - 1)**(-4))/(1 - u)
# T^(S)_0(x, y) = -u/(1 - u) + 1/(1 - u)
# T^(S)_1(x, y) = -u/((1 - u)*(u - 1)) + x*(-u/(1 - u) + 1/(1 - u)) + 1/((1 - u)*(u - 1))
# T^(S)_2(x, y) = -2*u*(1/(2*(u - 1)) + (u - 1)**(-2))/(1 - u) + x**2*(-u/(1 - u) + 1/(1 - u)) + 2*x*(-u/((1 - u)*(u - 1)) + 1/((1 - u)*(u - 1))) + 2*(1/(2*(u - 1)) + (u - 1)**(-2))/(1 - u)
# ...

# %%
import sympy as sp

# Define symbols
k, t, u, x, y = sp.symbols('k t u x y')

# Number of terms to compute
num_terms = 5
n_number = 5

# Define the generating function
# when alpha=2
generating_function = ((1 - u) / (sp.exp(t) - u))

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# List to store the tangent numbers
tangent_number = []

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    # Simplify the result
    I_n_simplified = sp.simplify(I_n)
    tangent_number.append(I_n_simplified)

# Display the tangent numbers E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n - k) * tangent_number[k] for k in range(n + 1))
    # Simplify the polynomial
    T_n_x_y_simplified = sp.simplify(T_n_x_y)
    polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 1
# E^(S)_1(x, y) = 1/(u - 1)
# E^(S)_2(x, y) = (u + 1)/(u**2 - 2*u + 1)
# E^(S)_3(x, y) = (u**2 + 4*u + 1)/(u**3 - 3*u**2 + 3*u - 1)
# E^(S)_4(x, y) = (u**3 + 11*u**2 + 11*u + 1)/(u**4 - 4*u**3 + 6*u**2 - 4*u + 1)
# T^(S)_0(x, y) = 1
# T^(S)_1(x, y) = (x*(u - 1) + 1)/(u - 1)
# T^(S)_2(x, y) = x**2 + 2*x/(u - 1) + (u + 1)/(u**2 - 2*u + 1)
# T^(S)_3(x, y) = (u**3*x**3 - 3*u**2*x**3 + 3*u**2*x**2 + 3*u**2*x + u**2 + 3*u*x**3 - 6*u*x**2 + 4*u - x**3 + 3*x**2 - 3*x + 1)/(u**3 - 3*u**2 + 3*u - 1)
# T^(S)_4(x, y) = (u**4*x**4 - 4*u**3*x**4 + 4*u**3*x**3 + 6*u**3*x**2 + 4*u**3*x + u**3 + 6*u**2*x**4 - 12*u**2*x**3 - 6*u**2*x**2 + 12*u**2*x + 11*u**2 - 4*u*x**4 + 12*u*x**3 - 6*u*x**2 - 12*u*x + 11*u + x**4 - 4*x**3 + 6*x**2 - 4*x + 1)/(u**4 - 4*u**3 + 6*u**2 - 4*u + 1)

# %% [markdown]
# Frobenius-Tangent

# %%
import sympy as sp

# Define symbols
k, t, u= sp.symbols('k t u')

# Set u = -1
#u = -1
#a = 1

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
#def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    #polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    #return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
#li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((1-u)  / (sp.exp(2 * t) -u))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    T_n_x_y_simplified = sp.simplify(T_n_x_y)
    polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = -u/(1 - u) + 1/(1 - u)
# E^(S)_1(x, y) = -2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))
# E^(S)_2(x, y) = -2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# E^(S)_3(x, y) = -6*u*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u) + 6*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u)
# E^(S)_4(x, y) = -24*u*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u) + 24*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u)
# T^(S)_0(x, y) = -u/(1 - u) + 1/(1 - u)
# T^(S)_1(x, y) = 1
# T^(S)_2(x, y) = -2*u/((1 - u)*(u - 1)) + x*(-u/(1 - u) + 1/(1 - u)) + 2/((1 - u)*(u - 1))
# T^(S)_3(x, y) = (u*x - x + 2)/(u - 1)
# T^(S)_4(x, y) = -2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + x**2*(-u/(1 - u) + 1/(1 - u)) + 2*x*(-2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# T^(S)_5(x, y) = (u**2*x**2 - 2*u*x**2 + 4*u*x + 4*u + x**2 - 4*x + 4)/(u**2 - 2*u + 1)
# ...

# %%
import sympy as sp

# Define symbols
k, t, u, a= sp.symbols('k t u a')

# Set u = -1
#u = -1
#a = 1

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
#def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    #polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    #return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
#li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((1-u)  / (sp.exp(2 * t) -u))**a

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 1
# E^(S)_1(x, y) = 2*a/(u - 1)
# E^(S)_2(x, y) = 4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2)
# E^(S)_3(x, y) = 8*a*(a - 2)*(a - 1)/(u - 1)**3 + 12*a*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 6*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2)
# E^(S)_4(x, y) = 16*a*(a - 3)*(a - 2)*(a - 1)/(u - 1)**4 + 48*a*(a - 2)*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1)**2 + 12*a*(a - 1)*((2/(u - 1) + 4/(u - 1)**2)**2 + 4*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2)/(u - 1)) + 24*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 2*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(u - 1) + 2/(3*(u - 1)) + 8/(3*(u - 1)**2))
# T^(S)_0(x, y) = 1
# T^(S)_1(x, y) = 2*a/(u - 1) + x
# T^(S)_2(x, y) = 4*a*x/(u - 1) + 4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2) + x**2
# ...

# %%
import sympy as sp

# Define the symbols
u, x, a = sp.symbols('u x a')

# Define the expressions for E^(S)_n(x, y)
E0 = 1
E1 = 2*a/(u - 1)
E2 = 4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2)
E3 = 8*a*(a - 2)*(a - 1)/(u - 1)**3 + 12*a*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 6*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2)
E4 = 16*a*(a - 3)*(a - 2)*(a - 1)/(u - 1)**4 + 48*a*(a - 2)*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1)**2 + 12*a*(a - 1)*((2/(u - 1) + 4/(u - 1)**2)**2 + 4*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2)/(u - 1)) + 24*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 2*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(u - 1) + 2/(3*(u - 1)) + 8/(3*(u - 1)**2))

# Define the expressions for T^(S)_n(x, y)
T0 = 1
T1 = 2*a/(u - 1) + x
T2 = 4*a*x/(u - 1) + 4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2) + x**2
T3 = 6*a*x**2/(u - 1) + 8*a*(a - 2)*(a - 1)/(u - 1)**3 + 12*a*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 6*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2) + x**3 + 3*x*(4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2))
T4 = 8*a*x**3/(u - 1) + 16*a*(a - 3)*(a - 2)*(a - 1)/(u - 1)**4 + 48*a*(a - 2)*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1)**2 + 12*a*(a - 1)*((2/(u - 1) + 4/(u - 1)**2)**2 + 4*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2)/(u - 1)) + 24*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 2*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(u - 1) + 2/(3*(u - 1)) + 8/(3*(u - 1)**2)) + x**4 + 6*x**2*(4*a*(a - 1)/(u - 1)**2 + 2*a*(2/(u - 1) + 4/(u - 1)**2)) + 4*x*(8*a*(a - 2)*(a - 1)/(u - 1)**3 + 12*a*(a - 1)*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 6*a*(2*(2/(u - 1) + 4/(u - 1)**2)/(u - 1) + 4/(3*(u - 1)) + 4/(u - 1)**2))

# Simplify each expression
E0_simplified = sp.simplify(E0)
E1_simplified = sp.simplify(E1)
E2_simplified = sp.simplify(E2)
E3_simplified = sp.simplify(E3)
E4_simplified = sp.simplify(E4)

T0_simplified = sp.simplify(T0)
T1_simplified = sp.simplify(T1)
T2_simplified = sp.simplify(T2)
T3_simplified = sp.simplify(T3)
T4_simplified = sp.simplify(T4)

# Display the simplified results
print("E^(S)_0(x, y) =", E0_simplified)
print("E^(S)_1(x, y) =", E1_simplified)
print("E^(S)_2(x, y) =", E2_simplified)
print("E^(S)_3(x, y) =", E3_simplified)
print("E^(S)_4(x, y) =", E4_simplified)

print("T^(S)_0(x, y) =", T0_simplified)
print("T^(S)_1(x, y) =", T1_simplified)
print("T^(S)_2(x, y) =", T2_simplified)
print("T^(S)_3(x, y) =", T3_simplified)
print("T^(S)_4(x, y) =", T4_simplified)
# Out:
# E^(S)_0(x, y) = 1
# E^(S)_1(x, y) = 2*a/(u - 1)
# E^(S)_2(x, y) = 4*a*(a + u)/(u**2 - 2*u + 1)
# E^(S)_3(x, y) = 8*a*(a**2 + 3*a*u + u**2 + u)/(u**3 - 3*u**2 + 3*u - 1)
# E^(S)_4(x, y) = 16*a*(a**3 + 6*a**2*u + 7*a*u**2 + 4*a*u + u**3 + 4*u**2 + u)/(u**4 - 4*u**3 + 6*u**2 - 4*u + 1)
# T^(S)_0(x, y) = 1
# T^(S)_1(x, y) = (2*a + x*(u - 1))/(u - 1)
# T^(S)_2(x, y) = (4*a*x*(u - 1)**2 + 4*a*(a - 1)*(u - 1) + 4*a*(2*u + (u - 1)**2 - 2) + x**2*(u - 1)**3)/(u - 1)**3
# T^(S)_3(x, y) = (6*a*x**2*(u - 1)**3 + 12*a*x*(u - 1)*(2*u + (a - 1)*(u - 1) + (u - 1)**2 - 2) + 8*a*(a - 2)*(a - 1)*(u - 1) + 24*a*(a - 1)*(2*u + (u - 1)**2 - 2) + 8*a*(6*u + (u - 1)**3 + 6*(u - 1)**2 - 6) + x**3*(u - 1)**4)/(u - 1)**4
# ...

# %% [markdown]
# Type 1 Poly-tangent

# %%
import sympy as sp

# Define symbols
k, t, u= sp.symbols('k t u')

# Set u = -1
#u = -1
#k = 1

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polylog_sum = sum((1-sp.exp(-2*t))**m / m**k for m in range(1, num_terms + 1))
    return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = li_k_approx*(1/t*(sp.exp(2*t)+1))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 4
# E^(S)_1(x, y) = 8/2**k
# E^(S)_2(x, y) = 16/3 + 32/3**k - 16/2**k
# E^(S)_3(x, y) = 192/4**k - 192/3**k + 64/2**k
# E^(S)_4(x, y) = 64/5 + 1536/5**k - 2304/4**k + 1152/3**k - 192/2**k
# T^(S)_0(x, y) = 4
# T^(S)_1(x, y) = 4*x + 8/2**k
# T^(S)_2(x, y) = 4*x**2 + 16/3 + 32/3**k + 16*x/2**k - 16/2**k
# T^(S)_3(x, y) = 4*x**3 + 3*x*(16/3 + 32/3**k - 16/2**k) + 192/4**k - 192/3**k + 24*x**2/2**k + 64/2**k
# T^(S)_4(x, y) = 4*x**4 + 6*x**2*(16/3 + 32/3**k - 16/2**k) + 4*x*(192/4**k - 192/3**k + 64/2**k) + 64/5 + 1536/5**k - 2304/4**k + 1152/3**k + 32*x**3/2**k - 192/2**k

# %% [markdown]
# Type 1 Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
k, t, u= sp.symbols('k t u')

# Set u = -1
#u = -1
#k = 1

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = li_k_approx*(1/t*(sp.exp(2*t)-u))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    T_n_x_y_simplified = sp.simplify(T_n_x_y)
    polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 1 - u**2
# E^(S)_1(x, y) = u**3/2 + u**2/2 + 3*u/2 + 3/2 - u*(u + 1)**2/2**k + (u + 1)**2/2**k
# E^(S)_2(x, y) = -u**4/3 - 2*u**3/3 - 2*u**2 + 2*u/3 + 7/3 - 2*u*(u + 1)**3/3**k + 2*(u + 1)**3/3**k - 2*u*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 2*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 4*(u + 1)**2/2**k
# E^(S)_3(x, y) = u**5/4 + 3*u**4/4 + 5*u**3/2 - u**2/2 + 5*u/4 + 15/4 - 6*u*(u + 1)**4/4**k + 6*(u + 1)**4/4**k - 6*u*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 6*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 12*(u + 1)**3/3**k - 6*u*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 6*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2/2**k
# ...

# %%
import sympy as sp

# Define the symbols
u, x, k = sp.symbols('u x k')

# Define the expressions for E^(S)_n(x, y)
E0 = 1 - u**2
E1 = u**3/2 + u**2/2 + 3*u/2 + 3/2 - u*(u + 1)**2/2**k + (u + 1)**2/2**k
E2 = -u**4/3 - 2*u**3/3 - 2*u**2 + 2*u/3 + 7/3 - 2*u*(u + 1)**3/3**k + 2*(u + 1)**3/3**k - 2*u*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 2*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 4*(u + 1)**2/2**k
E3 = u**5/4 + 3*u**4/4 + 5*u**3/2 - u**2/2 + 5*u/4 + 15/4 - 6*u*(u + 1)**4/4**k + 6*(u + 1)**4/4**k - 6*u*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 6*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 12*(u + 1)**3/3**k - 6*u*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 6*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2/2**k
E4 = -u**6/5 - 4*u**5/5 - 3*u**4 - 3*u**2 + 4*u/5 + 31/5 - 24*u*(u + 1)**5/5**k + 24*(u + 1)**5/5**k - 24*u*(u + 1)**4*(-2*u**2/(u + 1) - 4*u/(u + 1) - 2/(u + 1))/4**k + 24*(u + 1)**4*(-2*u**2/(u + 1) - 4*u/(u + 1) - 2/(u + 1))/4**k + 48*(u + 1)**4/4**k - 24*u*(u + 1)**3*(u**3/(2*(u + 1)) + 3*u**2/(2*(u + 1)) + 3*u/(2*(u + 1)) + 3*(-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(2*(u + 1)))/3**k + 48*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 24*(u + 1)**3*(u**3/(2*(u + 1)) + 3*u**2/(2*(u + 1)) + 3*u/(2*(u + 1)) + 3*(-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(2*(u + 1)))/3**k + 48*(u + 1)**3/3**k - 24*u*(u + 1)**2*(-u**4/(12*(u + 1)) - u**3/(3*(u + 1)) - u**2/(2*(u + 1)) - u/(3*(u + 1)) + 2*(-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))*(u**3/(6*(u + 1)) + u**2/(2*(u + 1)) + u/(2*(u + 1)) + 1/(6*(u + 1))) - 1/(12*(u + 1)))/2**k + 48*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 48*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 24*(u + 1)**2*(-u**4/(12*(u + 1)) - u**3/(3*(u + 1)) - u**2/(2*(u + 1)) - u/(3*(u + 1)) + 2*(-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))*(u**3/(6*(u + 1)) + u**2/(2*(u + 1)) + u/(2*(u + 1)) + 1/(6*(u + 1))) - 1/(12*(u + 1)))/2**k + 32*(u + 1)**2/2**k

# Define the expressions for T^(S)_n(x, y)
T0 = 1 - u**2
T1 = 1 - u**2
T2 = u**3/2 + u**2/2 + 3*u/2 + x*(1 - u**2) + 3/2 - u*(u + 1)**2/2**k + (u + 1)**2/2**k
T3 = (2**k*(u**3 + u**2 + 3*u - 2*x*(u**2 - 1) + 3) - 2*u*(u + 1)**2 + 2*(u + 1)**2)/(2*2**k)
T4 = -u**4/3 - 2*u**3/3 - 2*u**2 + 2*u/3 + x**2*(1 - u**2) + 2*x*(u**3/2 + u**2/2 + 3*u/2 + 3/2 - u*(u + 1)**2/2**k + (u + 1)**2/2**k) + 7/3 - 2*u*(u + 1)**3/3**k + 2*(u + 1)**3/3**k - 2*u*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 2*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 4*(u + 1)**2/2**k
T5 = (6*2**k*(1 - u)*(u + 1)**3 + 3*3**k*(2*u*(u + 1)*(u**2 + 2*u + 1) + x*(2**k*(u**3 + u**2 + 3*u + 3) - 2*u*(u + 1)**2 + 2*(u + 1)**2) + 4*(u + 1)**2 - 2*(u + 1)*(u**2 + 2*u + 1)) + 6**k*(-u**4 - 2*u**3 - 6*u**2 + 2*u + 3*x**2*(1 - u**2) + 7))/(3*6**k)
T6 = u**5/4 + 3*u**4/4 + 5*u**3/2 - u**2/2 + 5*u/4 + x**3*(1 - u**2) + 3*x**2*(u**3/2 + u**2/2 + 3*u/2 + 3/2 - u*(u + 1)**2/2**k + (u + 1)**2/2**k) + 3*x*(-u**4/3 - 2*u**3/3 - 2*u**2 + 2*u/3 + 7/3 - 2*u*(u + 1)**3/3**k + 2*(u + 1)**3/3**k - 2*u*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 2*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 4*(u + 1)**2/2**k) + 15/4 - 6*u*(u + 1)**4/4**k + 6*(u + 1)**4/4**k - 6*u*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 6*(u + 1)**3*(-3*u**2/(2*(u + 1)) - 3*u/(u + 1) - 3/(2*(u + 1)))/3**k + 12*(u + 1)**3/3**k - 6*u*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2*(-u**2/(u + 1) - 2*u/(u + 1) - 1/(u + 1))/2**k + 6*(u + 1)**2*(u**3/(3*(u + 1)) + u**2/(u + 1) + u/(u + 1) + (-u**2/(2*(u + 1)) - u/(u + 1) - 1/(2*(u + 1)))**2 + 1/(3*(u + 1)))/2**k + 12*(u + 1)**2/2**k
T7 = (-4*144**k*x*(6*2**k*(u - 1)*(u + 1)**3 + 6*3**k*(u + 1)*(u**2 - u*(u**2 + 2*u + 1) - 1) + 6**k*(u**4 + 2*u**3 + 6*u**2 - 2*u - 7)) + 24*216**k*(1 - u)*(u + 1)**4 + 48*288**k*(u + 1)**3 + 36*288**k*(u + 1)**2*(-u**2 + u*(u**2 + 2*u + 1) - 2*u - 1) + 6*432**k*(x**2*(2**k*(u**3 + u**2 + 3*u + 3) - 2*u*(u + 1)**2 + 2*(u + 1)**2) + 8*(u + 1)**2 - 8*(u + 1)*(u**2 + 2*u + 1)) + 2*432**k*(12*u*(u + 1)**2 - u*(12*u*(u + 1)**2 + 4*(u + 1)*(u**3 + 1) + 3*(u**2 + 2*u + 1)**2) + 4*(u + 1)*(u**3 + 1) + 3*(u**2 + 2*u + 1)**2) + 864**k*(u**5 + 3*u**4 + 10*u**3 - 2*u**2 + 5*u + 4*x**3*(1 - u**2) + 15))/(4*864**k)

# Simplify each expression
E0_simplified = sp.simplify(E0)
E1_simplified = sp.simplify(E1)
E2_simplified = sp.simplify(E2)
E3_simplified = sp.simplify(E3)
E4_simplified = sp.simplify(E4)

T0_simplified = sp.simplify(T0)
T1_simplified = sp.simplify(T1)
T2_simplified = sp.simplify(T2)
T3_simplified = sp.simplify(T3)
T4_simplified = sp.simplify(T4)
T5_simplified = sp.simplify(T5)
T6_simplified = sp.simplify(T6)
T7_simplified = sp.simplify(T7)

# Display the simplified results
print("E^(S)_0(x, y) =", E0_simplified)
print("E^(S)_1(x, y) =", E1_simplified)
print("E^(S)_2(x, y) =", E2_simplified)
print("E^(S)_3(x, y) =", E3_simplified)
print("E^(S)_4(x, y) =", E4_simplified)

print("T^(S)_0(x, y) =", T0_simplified)
print("T^(S)_1(x, y) =", T1_simplified)
print("T^(S)_2(x, y) =", T2_simplified)
print("T^(S)_3(x, y) =", T3_simplified)
print("T^(S)_4(x, y) =", T4_simplified)
print("T^(S)_5(x, y) =", T5_simplified)
print("T^(S)_7(x, y) =", T6_simplified)
print("T^(S)_7(x, y) =", T7_simplified)
# Out:
# E^(S)_0(x, y) = 1 - u**2
# E^(S)_1(x, y) = (2**k*(u**3 + u**2 + 3*u + 3.0) - 2*u*(u + 1)**2 + 2*(u + 1)**2)/(2*2**k)
# E^(S)_2(x, y) = (6*2**k*(1 - u)*(u + 1)**3 + 6*3**k*(u + 1)*(-u**2 + u*(u**2 + 2*u + 1) + 1) + 6**k*(-u**4 - 2*u**3 - 6*u**2 + 2*u + 7.0))/(3*6**k)
# E^(S)_3(x, y) = (144**k*(u**5 + 3*u**4 + 10*u**3 - 2*u**2 + 5*u + 15.0) + 24*36**k*(1 - u)*(u + 1)**4 + 48*48**k*(u + 1)**3 + 36*48**k*(u + 1)**2*(-u**2 + u*(u**2 + 2*u + 1) - 2*u - 1) - 48*72**k*u*(u + 1)**2 + 2*72**k*(12*u*(u + 1)**2 - u*(12*u*(u + 1)**2 + 4*(u + 1)*(u**3 + 1) + 3*(u**2 + 2*u + 1)**2) + 4*(u + 1)*(u**3 + 1) + 3*(u**2 + 2*u + 1)**2))/(4*144**k)
# ...

# %% [markdown]
# Type 1 higher-order Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
k, t,u, a= sp.symbols('k t u a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = (li_k_approx*(1/t*(sp.exp(2*t)-u)))**a

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    T_n_x_y_simplified = sp.simplify(T_n_x_y)
    polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = ((1 - u)*(u + 1))**a
# E^(S)_1(x, y) = a*((1 - u)*(u + 1))**a*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))
# E^(S)_2(x, y) = 2*((1 - u)*(u + 1))**a*(a*(a - 1)*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))**2/2 + a*(u**4/(6*(u - 1)*(u + 1)) + u**3/(3*(u - 1)*(u + 1)) + u**2/((u - 1)*(u + 1)) - u/(3*(u - 1)*(u + 1)) - 7/(6*(u - 1)*(u + 1)) + 40**k*u*(u + 1)**2/(120**k*(u - 1)) - 40**k*(u + 1)**2/(120**k*(u - 1)) - 2*60**k*u**2*(u + 1)/(120**k*(u - 1)) + 60**k*u*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1)) - 60**k*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1))))
# ...

# %% [markdown]
# Type 1 higher-order cosine Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
y, k, t,u, a, x= sp.symbols('y k t u a x')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((li_k_approx*(1/t*(sp.exp(2*t)-u)))**a)*sp.cos(y*t)

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = ((1 - u)*(u + 1))**a
# E^(S)_1(x, y) = a*((1 - u)*(u + 1))**a*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))
# E^(S)_2(x, y) = -y**2*((1 - u)*(u + 1))**a + 2*((1 - u)*(u + 1))**a*(a*(a - 1)*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))**2/2 + a*(u**4/(6*(u - 1)*(u + 1)) + u**3/(3*(u - 1)*(u + 1)) + u**2/((u - 1)*(u + 1)) - u/(3*(u - 1)*(u + 1)) - 7/(6*(u - 1)*(u + 1)) + 40**k*u*(u + 1)**2/(120**k*(u - 1)) - 40**k*(u + 1)**2/(120**k*(u - 1)) - 2*60**k*u**2*(u + 1)/(120**k*(u - 1)) + 60**k*u*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1)) - 60**k*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1))))
# ...

# %% [markdown]
# Type 1 higher-order sine Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
y, k, t,u, a= sp.symbols('y k t u a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polylog_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polylog_sum = sum((1-sp.exp(-(1+u)*t))**m / m**k for m in range(1, num_terms + 1))
    return polylog_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
li_k_approx = polylog_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((li_k_approx*(1/t*(sp.exp(2*t)-u)))**a)*sp.sin(y*t)

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 0
# E^(S)_1(x, y) = y*((1 - u)*(u + 1))**a
# E^(S)_2(x, y) = 2*a*y*((1 - u)*(u + 1))**a*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))
# E^(S)_3(x, y) = -y**3*((1 - u)*(u + 1))**a + 6*y*((1 - u)*(u + 1))**a*(a*(a - 1)*(-u**3/(2*(u - 1)*(u + 1)) - u**2/(2*(u - 1)*(u + 1)) - 3*u/(2*(u - 1)*(u + 1)) - 3/(2*(u - 1)*(u + 1)) + 60**k*u*(u + 1)/(120**k*(u - 1)) - 60**k*(u + 1)/(120**k*(u - 1)))**2/2 + a*(u**4/(6*(u - 1)*(u + 1)) + u**3/(3*(u - 1)*(u + 1)) + u**2/((u - 1)*(u + 1)) - u/(3*(u - 1)*(u + 1)) - 7/(6*(u - 1)*(u + 1)) + 40**k*u*(u + 1)**2/(120**k*(u - 1)) - 40**k*(u + 1)**2/(120**k*(u - 1)) - 2*60**k*u**2*(u + 1)/(120**k*(u - 1)) + 60**k*u*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1)) - 60**k*(u + 1)*(u**2/(u + 1) + 2*u/(u + 1) + 1/(u + 1))/(120**k*(u - 1))))
# ...

# %% [markdown]
# Type 2 poly-tangent

# %%
import sympy as sp

# Define symbols
k, t=sp.symbols('k t')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

x = sp.symbols('x')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+2*t)**m / (m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((ei_k_approx*(1/t*(sp.exp(2*t)+1))))
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 4
# E^(S)_1(x, y) = 8/2**k
# E^(S)_2(x, y) = 32/3 + 64/3**k - 16/2**k
# E^(S)_3(x, y) = -24 + 1152/4**k - 384/3**k + 128/2**k
# E^(S)_4(x, y) = 1056/5 + 36864/5**k - 13824/4**k + 3840/3**k - 832/2**k
# T^(S)_0(x, y) = 4
# T^(S)_1(x, y) = 4*x + 8/2**k
# T^(S)_2(x, y) = 4*x**2 + 32/3 + 64/3**k + 16*x/2**k - 16/2**k
# T^(S)_3(x, y) = 4*x**3 + 3*x*(32/3 + 64/3**k - 16/2**k) - 24 + 1152/4**k - 384/3**k + 24*x**2/2**k + 128/2**k
# T^(S)_4(x, y) = 4*x**4 + 6*x**2*(32/3 + 64/3**k - 16/2**k) + 4*x*(-24 + 1152/4**k - 384/3**k + 128/2**k) + 1056/5 + 36864/5**k - 13824/4**k + 3840/3**k + 32*x**3/2**k - 832/2**k

# %% [markdown]
# Type 2 higher-order poly-tangent

# %%
import sympy as sp

# Define symbols
k, t, a=sp.symbols('k t a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+2*t)**m / (m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ((ei_k_approx*(1/t*(sp.exp(2*t)+1)))**a)
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 4**a
# E^(S)_1(x, y) = 2*4**a*60**k*a/120**k
# E^(S)_2(x, y) = 2*4**a*(a*(4/3 + 8*40**k/120**k - 2*60**k/120**k) + 2*60**(2*k)*a*(a - 1)/120**(2*k))
# E^(S)_3(x, y) = 6*4**a*(a*(-1 + 48*30**k/120**k - 16*40**k/120**k + 16*60**k/(3*120**k)) + 2*60**k*a*(a - 1)*(4/3 + 8*40**k/120**k - 2*60**k/120**k)/120**k + 4*60**(3*k)*a*(a - 2)*(a - 1)/(3*120**(3*k)))
# E^(S)_4(x, y) = 24*4**a*(a*(a - 1)*((4/3 + 8*40**k/120**k - 2*60**k/120**k)**2 + 4*60**k*(-1 + 48*30**k/120**k - 16*40**k/120**k + 16*60**k/(3*120**k))/120**k)/2 + a*(11/5 + 384*24**k/120**k - 144*30**k/120**k + 40*40**k/120**k - 26*60**k/(3*120**k)) + 2*60**(2*k)*a*(a - 2)*(a - 1)*(4/3 + 8*40**k/120**k - 2*60**k/120**k)/120**(2*k) + 2*60**(4*k)*a*(a - 3)*(a - 2)*(a - 1)/(3*120**(4*k)))
# T^(S)_0(x, y) = 4**a
# T^(S)_1(x, y) = 4**a*x + 2*4**a*60**k*a/120**k
# T^(S)_2(x, y) = 4**a*x**2 + 2*4**a*(a*(4/3 + 8*40**k/120**k - 2*60**k/120**k) + 2*60**(2*k)*a*(a - 1)/120**(2*k)) + 4*4**a*60**k*a*x/120**k
# ...

# %% [markdown]
# Type 2 Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
k, t,u = sp.symbols('k t u')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+(1-u)*t)**m /(m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ei_k_approx*(1/t*(sp.exp(2*t)-u))
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = -u*(1 - u) - u + 1
# E^(S)_1(x, y) = u*(1 - u)**2/2 - 2*u - (1 - u)**2/2 + 2 - u*(1 - u)**2*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k + (1 - u)**2*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k
# E^(S)_2(x, y) = -2*u*(1 - u)**3/3 - 4*u + 2*(1 - u)**3/3 - 2*(1 - u)**2 + 4 - 4*u*(1 - u)**3*(-3*u/(u - 1) + 3*(-u/(u - 1) + 1 + 1/(u - 1))**2 + 4 + 3/(u - 1))/3**k + 4*(1 - u)**3*(-3*u/(u - 1) + 3*(-u/(u - 1) + 1 + 1/(u - 1))**2 + 4 + 3/(u - 1))/3**k - 2*u*(1 - u)**2*((1 - u)**2*(-u/(u - 1) + 1 + 1/(u - 1))/(u - 1) + (1 - u)**2/(u - 1))/2**k + 2*(1 - u)**2*((1 - u)**2*(-u/(u - 1) + 1 + 1/(u - 1))/(u - 1) + (1 - u)**2/(u - 1))/2**k + 4*(1 - u)**2*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k
# ...

# %% [markdown]
# Type 2 higher-order Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
k, t,u, a = sp.symbols('k t u a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+(1-u)*t)**m /(m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ei_k_approx*(1/t*(sp.exp(2*t)-u)**a)
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = (1 - u)*(1 - u)**a
# E^(S)_1(x, y) = -2*a*(1 - u)*(1 - u)**a/(u - 1) - (1 - u)**2*(1 - u)**a/2 + (1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k
# E^(S)_2(x, y) = 2*a*(1 - u)**2*(1 - u)**a/(u - 1) + 2*(1 - u)**3*(1 - u)**a/3 + 2*(1 - u)*(1 - u)**a*(2*a*(a - 1)/(u - 1)**2 - 2*a/(u - 1)) + 4*(1 - u)**3*(1 - u)**a*(-3*u/(u - 1) + 3*(-u/(u - 1) + 1 + 1/(u - 1))**2 + 4 + 3/(u - 1))/3**k - 4*a*(1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/(2**k*(u - 1)) + 2*(1 - u)**2*(1 - u)**a*((1 - u)**2*(-u/(u - 1) + 1 + 1/(u - 1))/(u - 1) + (1 - u)**2/(u - 1))/2**k
# ...

# %% [markdown]
# Type 2 higher-order cosine Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
y, k, t,u, a= sp.symbols('y k t u a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+(1-u)*t)**m /(m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ei_k_approx*(1/t*(sp.exp(2*t)-u)**a)* sp.cos(y*t)
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = (1 - u)*(1 - u)**a
# E^(S)_1(x, y) = -2*a*(1 - u)*(1 - u)**a/(u - 1) - (1 - u)**2*(1 - u)**a/2 + (1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k
# E^(S)_2(x, y) = 2*a*(1 - u)**2*(1 - u)**a/(u - 1) - y**2*(1 - u)*(1 - u)**a + 2*(1 - u)**3*(1 - u)**a/3 + 2*(1 - u)*(1 - u)**a*(2*a*(a - 1)/(u - 1)**2 - 2*a/(u - 1)) + 4*(1 - u)**3*(1 - u)**a*(-3*u/(u - 1) + 3*(-u/(u - 1) + 1 + 1/(u - 1))**2 + 4 + 3/(u - 1))/3**k - 4*a*(1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/(2**k*(u - 1)) + 2*(1 - u)**2*(1 - u)**a*((1 - u)**2*(-u/(u - 1) + 1 + 1/(u - 1))/(u - 1) + (1 - u)**2/(u - 1))/2**k
# ...

# %% [markdown]
# Type 2 higher-order sine Frobenius-type poly-tangent

# %%
import sympy as sp

# Define symbols
y, k, t,u, a= sp.symbols('y k t u a')

#when k=2
#def polylog(x2):
#   return sp.summation((1-sp.exp(-1*(1-u)*t))**m / m**2, (m, 1, sp.oo))

#x, m = sp.symbols('x m')

# Define the polylogarithm series: Li_2(x) = sum(x^m / m^2)
def polyexpo_k(x, num_terms):
    # Sum the first `num_terms` of the series
    polyexpo_sum = sum(sp.log(1+(1-u)*t)**m /(m**k)*sp.factorial(m-1) for m in range(1, num_terms + 1))
    return polyexpo_sum

# Number of terms to compute
num_terms = 5

# Generate the first few terms of the polylogarithmic function Li_2(x)
ei_k_approx = polyexpo_k(x, num_terms)

# Define the generating function
#when alpha=2
generating_function = ei_k_approx*(1/t*(sp.exp(2*t)-u)**a)* sp.sin(y*t)
# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get E^(S)_n(x, y)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get E^(S)_n(x, y)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials E^(S)_n(x, y)
for n, T_n in enumerate(tangent_number):
    print(f"E^(S)_{n}(x, y) = {T_n}")

# Now, generate the polynomials E^(S)_n(x, y)
polynomials_x_y = []
for n in range(n_number):
    T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x_y.append(T_n_x_y)
    # Simplify the polynomial
    #T_n_x_y_simplified = sp.simplify(T_n_x_y)
    #polynomials_x_y.append(T_n_x_y_simplified)

# Display the polynomials E^(S)_n(x, y)
for n, T_n_x_y in enumerate(polynomials_x_y):
    print(f"T^(S)_{n}(x, y) = {T_n_x_y}")
# Out:
# E^(S)_0(x, y) = 0
# E^(S)_1(x, y) = y*(1 - u)*(1 - u)**a
# E^(S)_2(x, y) = -4*a*y*(1 - u)*(1 - u)**a/(u - 1) - y*(1 - u)**2*(1 - u)**a + 2*y*(1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/2**k
# E^(S)_3(x, y) = 6*a*y*(1 - u)**2*(1 - u)**a/(u - 1) - y**3*(1 - u)*(1 - u)**a + 2*y*(1 - u)**3*(1 - u)**a + 6*y*(1 - u)*(1 - u)**a*(2*a*(a - 1)/(u - 1)**2 - 2*a/(u - 1)) + 12*y*(1 - u)**3*(1 - u)**a*(-3*u/(u - 1) + 4 + 3/(u - 1))/3**k - 12*a*y*(1 - u)**2*(1 - u)**a*(-2*u/(u - 1) + (-u/(u - 1) + 1 + 1/(u - 1))**2 + 3 + 2/(u - 1))/(2**k*(u - 1)) + 6*y*(1 - u)**2*(1 - u)**a*((1 - u)**2*(-u/(u - 1) + 1 + 1/(u - 1))/(u - 1) + (1 - u)**2/(u - 1))/2**k
# ...
